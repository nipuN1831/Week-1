# %%
import numpy as np
from skimage import io
from PIL import Image
photo= io.imread('download1.jpg')
io.imshow(photo[::-1])

# %%
arr=np.array(photo)
arr
# Out:
# array([[[136, 122, 148],
#         [136, 121, 150],
#         [156, 136, 171],
#         ...,
#         [190, 195, 173],
#         [182, 187, 164],
#         [195, 201, 175]],
#
#        [[137, 123, 149],
#         [137, 122, 151],
#         [150, 131, 163],
#         ...,
#         [192, 196, 179],
#         [187, 192, 172],
#         [193, 198, 176]],
#
#        [[136, 121, 150],
#         [138, 123, 152],
#         [143, 124, 156],
#         ...,
#         [208, 210, 197],
#         [209, 211, 197],
#         [210, 213, 196]],
#
#        ...,
#
#        [[ 83,  45,  84],
#         [ 86,  43,  86],
#         [ 88,  41,  87],
#         ...,
#         [219, 219, 229],
#         [220, 220, 230],
#         [220, 220, 230]],
#
#        [[ 89,  51, 100],
#         [ 82,  42,  92],
#         [ 76,  32,  85],
#         ...,
#         [219, 219, 229],
#         [220, 220, 230],
#         [220, 220, 230]],
#
#        [[ 76,  37,  92],
#         [ 76,  35,  91],
#         [ 77,  32,  89],
# ...

# %%
img=Image.fromarray(arr)
img.save('my.png')
img.show()

# %%
gray= np.dot(arr[...,:3],[0.2989, 0.5870, 0.1140])
io.imshow(gray,cmap="gray")
