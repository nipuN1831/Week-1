# %%
import numpy as np

# %% [markdown]
# ## Loading the Image

# %%
from skimage import io
photo = io.imread('/content/kratosw1.jpg')
type(photo)
# Out:
# numpy.ndarray

# %%
photo.shape
# Out:
# (1000, 1000, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(photo)

# %% [markdown]
# ## Inverting the image colors

# %%
from PIL import Image

img = Image.open('/content/kratosw1.jpg')
array = np.array(img)

array = 255 - array

invimg = Image.fromarray(array)
invimg.save('/content/kratosw1.jpg')

# %%
photo1 = io.imread('/content/kratosw1.jpg')
plt.imshow(photo1)
